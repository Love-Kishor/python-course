# %% [markdown]
# # talking to OS

# %%
#import OS is used
#from OS import method, is used to import specific method

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'contorls.ipynb',
#  'day 5.ipynb',
#  'day 6.ipynb',
#  'day_2.ipynb',
#  'day_3.ipynb',
#  'day_4.ipynb']

# %%
os.chdir("C:\\Users\acer1\Desktop\Camera")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-ab2ce070aa88> in <module>
# ----> 1 os.chdir("C:\\Users\acer1\Desktop\Camera")
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: 'C:\\Users\x07cer1\\Desktop\\Camera'

# %%
source="C:\\Users\\acer1\\Desktop\\Camera"

# %%
os.chdir(source)

# %%
os.listdir()
# Out:
# ['20180109_203708.jpg',
#  '20180109_203715.jpg',
#  '20180109_203717.jpg',
#  '20180110_105651.jpg',
#  '20180110_105721.jpg',
#  '20180110_105732.jpg',
#  '20180110_105735.jpg',
#  '20180110_105741.jpg',
#  '20180110_174516.jpg',
#  '20180110_174518.jpg',
#  '20180110_174519.jpg',
#  '20180110_174524.jpg',
#  '20180110_174525.jpg',
#  '20180110_174526.jpg',
#  '20180110_174555.jpg',
#  '20180110_174558.jpg',
#  '20180110_174559.jpg',
#  '20180110_174601.jpg',
#  '20180110_174625.jpg',
#  '20180112_163513.jpg',
#  '20180113_155723.jpg',
#  '20180113_161124.jpg',
#  '20180113_161906.jpg',
#  '20180113_161909.jpg',
#  '20180113_161914.jpg',
#  '20180113_161915.jpg',
#  '20180113_161916.jpg',
#  '20180113_162014.jpg',
#  '20180113_162016.jpg',
#  '20180113_162018.jpg',
#  '20180113_162020.jpg',
#  '20180113_162023.jpg',
#  '20180113_162139.jpg',
#  '20180113_162141.jpg',
#  '20180113_162144.jpg',
#  '20180113_162155(0).jpg',
#  '20180113_162155.jpg',
#  '20180113_162204.jpg',
# ...

# %%
valid_ext = "jpg","jpeg"
for i, file in enumerate(os.listdir()):
    ext = file.split('.')[-1]
    if ext.lower() in valid_ext:
        os.rename(file,f"camera{i}.{ext}")

# %%
#task...make different folder for jpeg and put them in that folder.
